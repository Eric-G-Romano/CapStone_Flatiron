# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time 
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
import requests
from bs4 import BeautifulSoup

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import re
import os

# %%
url = 'https://coinmarketcap.com/currencies/ethereum/news/'
html = requests.get(url)
soup = BeautifulSoup(html.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, shrink-to-fit=no" name="viewport"/>
#   <link crossorigin="anonymous" href="https://s2.coinmarketcap.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://s2.coinmarketcap.com" rel="dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://s3.coinmarketcap.com" rel="preconnect"/>
#   <link crossorigin="anonymous" href="https://s3.coinmarketcap.com" rel="dns-prefetch"/>
#   <link href="//www.googletagmanager.com" rel="preconnect"/>
#   <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/cmc-v2/CMC-V2.woff" rel="preload" type="font/woff2"/>
#   <meta content="EDc1reqlQ-zAgeRrrgAxRXNK-Zs9JgpE9a0wdaoSO9A" name="google-site-verification"/>
#   <meta content="CoinMarketCap" property="og:site_name"/>
# ...

# %%
description=[]
description.append([i for i in soup.find_all(class_='sc-16r8icm-0 hKZfDX container')])

# %%
description[0][0].attrs
# Out:
# {'class': ['sc-16r8icm-0', 'hKZfDX', 'container']}

# %%
import os
os.path.exists("C:/Users/egust/chromedriver.exe")
# Out:
# True

# %%
driver= webdriver.Chrome(executable_path="C:/Users/egust/chromedriver.exe")
driver.implicitly_wait(100)
driver.get(url)

# %%
driver.page_source
# Out:
# '<html lang="en"><head><meta charset="utf-8"><meta http-equiv="x-ua-compatible" content="ie=edge"><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, shrink-to-fit=no"><link rel="preconnect" href="https://s2.coinmarketcap.com" crossorigin="anonymous"><link rel="dns-prefetch" href="https://s2.coinmarketcap.com" crossorigin="anonymous"><link rel="preconnect" href="https://s3.coinmarketcap.com" crossorigin="anonymous"><link rel="dns-prefetch" href="https://s3.coinmarketcap.com" crossorigin="anonymous"><link rel="preconnect" href="//www.googletagmanager.com"><link rel="preload" href="https://s2.coinmarketcap.com/static/cloud/fonts/cmc-v2/CMC-V2.woff" as="font" type="font/woff2" crossorigin="anonymous"><meta name="google-site-verification" content="EDc1reqlQ-zAgeRrrgAxRXNK-Zs9JgpE9a0wdaoSO9A"><meta property="og:site_name" content="CoinMarketCap"><meta property="og:type" content="website"><meta name="twitter:card" content="summary_large_im
# ...

# %%
soup_level1=BeautifulSoup(driver.page_source, 'lxml')

# %%
soup_level1.prettify()
# Out:
# '<html lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="ie=edge" http-equiv="x-ua-compatible"/>\n  <meta content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no, shrink-to-fit=no" name="viewport"/>\n  <link crossorigin="anonymous" href="https://s2.coinmarketcap.com" rel="preconnect"/>\n  <link crossorigin="anonymous" href="https://s2.coinmarketcap.com" rel="dns-prefetch"/>\n  <link crossorigin="anonymous" href="https://s3.coinmarketcap.com" rel="preconnect"/>\n  <link crossorigin="anonymous" href="https://s3.coinmarketcap.com" rel="dns-prefetch"/>\n  <link href="//www.googletagmanager.com" rel="preconnect"/>\n  <link as="font" crossorigin="anonymous" href="https://s2.coinmarketcap.com/static/cloud/fonts/cmc-v2/CMC-V2.woff" rel="preload" type="font/woff2"/>\n  <meta content="EDc1reqlQ-zAgeRrrgAxRXNK-Zs9JgpE9a0wdaoSO9A" name="google-site-verification"/>\n  <meta content="CoinMarketCap" property="og:site_name"/>\n  <meta content="website" property
# ...

# %%
containers = []
containers.append(soup_level1.find_all(class_='dgjl35-5 inpsKo'))

# %%
len(containers[0])
# Out:
# 5

# %%
print(containers[0][0].find_all('h3')[0].text)
print(containers[0][0].find_all(class_='sc-1eb5slv-0 dgjl35-7 imVTnY')[0].text)
print(containers[0][0].find_all(class_='sc-1eb5slv-0 kDEzev')[0].text)
# Out:
# Ark Investment tips $20M into Grayscale Ethereum Trust
# Cointelegraph.com News
# 49 minutes ago

# %%
print(containers[0][1].find_all('h3')[0].text)
print(containers[0][1].find_all(class_='sc-1eb5slv-0 dgjl35-7 imVTnY')[0].text)
print(containers[0][1].find_all(class_='sc-1eb5slv-0 kDEzev')[0].text)
# Out:
# Cardano’s parent company IOHK announces an Ethereum ERC20 token converter is on its way
# CryptoSlate
# 1 hour ago

# %%
print(containers[0][2].find_all('h3')[0].text)
print(containers[0][2].find_all(class_='sc-1eb5slv-0 dgjl35-7 imVTnY')[0].text)
print(containers[0][2].find_all(class_='sc-1eb5slv-0 kDEzev')[0].text)
# Out:
# Comedian Steve Harvey Selling NFT for Charity, Holds Bitcoin and Ethereum
# Decrypt
# 4 hours ago

# %%
headline = []
news_center = []
time = []

for i in range(len(containers[0])):
    headline.append(containers[0][i].find_all('h3')[0].text)
    news_center.append(containers[0][i].find_all(class_='sc-1eb5slv-0 dgjl35-7 imVTnY')[0].text)
    time.append(containers[0][i].find_all(class_='sc-1eb5slv-0 kDEzev')[0].text)

# %%
headline
# Out:
# ['Ark Investment tips $20M into Grayscale Ethereum Trust ',
#  'Cardano’s parent company IOHK announces an Ethereum ERC20 token converter is on its way',
#  'Comedian Steve Harvey Selling NFT for Charity, Holds Bitcoin and Ethereum',
#  'Layer-2 Ethereum trading platform DeversiFi raises $5M in new funding round',
#  "NVIDIA Isn't Done Making Graphics Cards ‘Less Desirable’ for Ethereum Miners"]
